# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider

# %%
# Create subplot
fig, ax = plt.subplots()
plt.subplots_adjust(bottom=0.3)
ax.set_ylim(-500000, 500000)
ax.set_xlim(-50, 50)

E_0 = 0.5
a_ = 0.5

# Create and plot sine wave
x = np.arange(-50, 50, 0.001)
V = (E_0/a_**4)*(x**4) + (4*a_*x**3)- (8*(a_**2)*(x**2))
l, = plt.plot(x,V)

axE_0 = plt.axes([0.25, 0.0, 0.65, 0.03])
axa_ = plt.axes([0.25, 0.1, 0.65, 0.03])

E_0 = Slider(axE_0, 'E_0', 0.0, 20.0, valstep=0.1)
a_ = Slider(axa_, 'a', 0.0, 20.0, valstep=0.1)



def update(val):
    E0_val = E_0.val
    a_val = a_.val
    l.set_ydata((E0_val/a_val**4)*(x**4) + (4*a_val*x**3)- (8*(a_val**2)*(x**2)))
    eq1_val = (-12*a_val + sqrt(144*(a_val**2)+256/(a_val**2)) )/(8*E0_val/(a_val**4))
    eq2_val = (-12*a_val - sqrt(144*(a_val**2)+256/(a_val**2)) )/(8*E0_val/(a_val**4))
    ax.text(0, -0.2, s=f'stable equillibrium: x = {eq1_val}, {eq2_val}', transform=ax.transAxes)
    time.sleep(2)
    del gca().texts[-1]
        

a_.on_changed(update)
E_0.on_changed(update)


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="788.14935492002">
