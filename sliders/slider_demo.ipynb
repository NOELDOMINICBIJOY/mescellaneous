# %%
# %matplotlib notebook
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt
import scienceplots

plt.style.use(['science', 'notebook', 'dark_background'])
plt.style.use(['science', 'notebook', 'dark_background', 'grid'])
plt.style.use(['science', 'notebook', 'dark_background'])

# %%
x = np.linspace(0, 2 * np.pi, 10000)
fig = plt.figure(figsize=(9,5))
ax = fig.add_subplot(1, 1, 1)
line, = ax.plot(x, np.sin(x))

A = 4.00

def update(A = A, w = 1.000, phi = 0.000):
    line.set_ydata(A*np.sin(w * x + phi))
    fig.canvas.draw_idle()

ax.set_xlim(0, 6)
ax.set_ylim(-A-2, A+2)

interact(update);
# Out:
# <img src="data:image/png;base64,..." width="899.9999731779106">
# interactive(children=(FloatSlider(value=4.0, description='A', max=12.0, min=-4.0), FloatSlider(value=1.0, desc…
